# %% [markdown]
# <a href="https://colab.research.google.com/github/MyintHtun10/NASA/blob/main/NASA_dataEntry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# 1. NASA Sea Level Data
data = {
    "Year": [
        2000, 2001, 2002, 2003, 2004, 2005,
        2006, 2007, 2008, 2009, 2010, 2011,
        2012, 2013, 2014, 2015, 2016, 2017,
        2018, 2019, 2020, 2021, 2022, 2023,
        2024, 2025
    ],
    "GMSL": [
        18.70, 23.80, 25.91, 28.93, 30.62, 34.65,
        36.14, 37.35, 40.95, 44.45, 46.25, 45.51,
        55.32, 57.91, 60.42, 69.26, 73.33, 73.80,
        76.24, 82.73, 85.21, 89.60, 91.68, 97.03,
        100.68, 100.96
    ]
}

# 2. Create DataFrame
df = pd.DataFrame(data)

print("NASA Sea Level Data")
print(df)
